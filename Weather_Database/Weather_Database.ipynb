# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if not city in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 739

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=e228d3553d8582d93ea89c969a77089e

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat = city_weather["coord"]["lat"]
        lng = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        weather_description = city_weather['weather'][0]['description']
        country = city_weather['sys']['country']
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": lat,
                          "Lng": lng,
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": clouds,
                          "Wind Speed": wind,
                          "Country": country,
                          "Current Description": weather_description})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | bereda
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | belmonte
# Processing Record 6 of Set 1 | lata
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | kasongo-lunda
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | usevya
# Processing Record 11 of Set 1 | bambous virieux
# Processing Record 12 of Set 1 | provideniya
# Processing Record 13 of Set 1 | richards bay
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | honningsvag
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | bouna
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | constitucion
# Processing Record 21 of Set 1 | zakamensk
# Processing Record 22 of Set 1 | kirakira
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | kabare
# Processing Record 25 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 1 | cooma
# Processing Record 27 of Set 1 | saint-augustin
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | hobyo
# Processing Record 30 of Set 1 | serafimovskiy
# Processing Record 31 of Set 1 | leningradskiy
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | saldanha
# Processing Record 35 of Set 1 | ketchikan
# Processing Record 36 of Set 1 | dwarka
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | los llanos de aridane
# Processing Record 39 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | gualaquiza
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | marsh harbour
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | hualmay
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | nome
# Processing Record 48 of Set 1 | mbandaka
# Processing Record 49 of Set 1 | santa isabel
# Processing Record 50 of Set 1 | airai
# Processing Record 1 of Set 2 | namibe
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | laela
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | sechura
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | vila
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | kraksaan
# Processing Record 12 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 2 | chokurdakh
# Processing Record 14 of Set 2 | bose
# Processing Record 15 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 18 of Set 2 | te anau
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | waingapu
# Processing Record 21 of Set 2 | mount gambier
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | severo-kurilsk
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | zhangye
# Processing Record 26 of Set 2 | amalapuram
# Processing Record 27 of Set 2 | thinadhoo
# Processing Record 28 of Set 2 | sussex
# Processing Record 29 of Set 2 | tvedestrand
# Processing Record 30 of Set 2 | kruisfontein
# Processing Record 31 of Set 2 | mataura
# Processing Record 32 of Set 2 | esil
# Processing Record 33 of Set 2 | susangerd
# Processing Record 34 of Set 2 | tagusao
# Processing Record 35 of Set 2 | salalah
# Processing Record 36 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 37 of Set 2 | esteli
# Processing Record 38 of Set 2 | havre-saint-pierre
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | sokolo
# Processing Record 43 of Set 2 | gouyave
# Processing Record 44 of Set 2 | manggar
# Processing Record 45 of Set 2 | cabo san lucas
# Processing Record 46 of Set 2 | naze
# Processing Record 47 of Set 2 | mogadishu
# Processing Record 48 of Set 2 | kodiak
# Processing Record 49 of Set 2 | kavieng
# Processing Record 50 of Set 2 | sao joao da barra
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 4 of Set 3 | kaeo
# Processing Record 5 of Set 3 | starozhilovo
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | harper
# Processing Record 8 of Set 3 | sibu
# Processing Record 9 of Set 3 | vao
# Processing Record 10 of Set 3 | awjilah
# Processing Record 11 of Set 3 | banjar
# Processing Record 12 of Set 3 | lorengau
# Processing Record 13 of Set 3 | sahrak
# City not found. Skipping...
# Processing Record 14 of Set 3 | luderitz
# Processing Record 15 of Set 3 | egvekinot
# Processing Record 16 of Set 3 | narsaq
# Processing Record 17 of Set 3 | lamu
# Processing Record 18 of Set 3 | nikolskoye
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | yenagoa
# Processing Record 21 of Set 3 | cockburn town
# Processing Record 22 of Set 3 | butaritari
# Processing Record 23 of Set 3 | olinda
# Processing Record 24 of Set 3 | victoria
# Processing Record 25 of Set 3 | teo
# Processing Record 26 of Set 3 | port blair
# Processing Record 27 of Set 3 | hambantota
# Processing Record 28 of Set 3 | aswan
# Processing Record 29 of Set 3 | dikson
# Processing Record 30 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 3 | clyde river
# Processing Record 32 of Set 3 | hasaki
# Processing Record 33 of Set 3 | broome
# Processing Record 34 of Set 3 | auki
# Processing Record 35 of Set 3 | port elizabeth
# Processing Record 36 of Set 3 | soyo
# Processing Record 37 of Set 3 | ponnani
# Processing Record 38 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 3 | soure
# Processing Record 40 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 3 | gamba
# Processing Record 42 of Set 3 | bac lieu
# Processing Record 43 of Set 3 | anloga
# Processing Record 44 of Set 3 | faanui
# Processing Record 45 of Set 3 | opunake
# Processing Record 46 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 47 of Set 3 | longyearbyen
# Processing Record 48 of Set 3 | jacksonville
# Processing Record 49 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 3 | iquitos
# Processing Record 1 of Set 4 | upernavik
# Processing Record 2 of Set 4 | saskylakh
# Processing Record 3 of Set 4 | san vicente
# Processing Record 4 of Set 4 | yamada
# Processing Record 5 of Set 4 | romny
# Processing Record 6 of Set 4 | port keats
# Processing Record 7 of Set 4 | atasu
# Processing Record 8 of Set 4 | kununurra
# Processing Record 9 of Set 4 | katsuura
# Processing Record 10 of Set 4 | castro
# Processing Record 11 of Set 4 | bitung
# Processing Record 12 of Set 4 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 13 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 4 | hami
# Processing Record 15 of Set 4 | yellowknife
# Processing Record 16 of Set 4 | acari
# Processing Record 17 of Set 4 | ponta do sol
# Processing Record 18 of Set 4 | cherskiy
# Processing Record 19 of Set 4 | klaksvik
# Processing Record 20 of Set 4 | nyurba
# Processing Record 21 of Set 4 | yurga
# Processing Record 22 of Set 4 | saint george
# Processing Record 23 of Set 4 | huautla
# Processing Record 24 of Set 4 | lagoa
# Processing Record 25 of Set 4 | kasungu
# Processing Record 26 of Set 4 | yasothon
# Processing Record 27 of Set 4 | sabha
# Processing Record 28 of Set 4 | avarua
# Processing Record 29 of Set 4 | kurchum
# Processing Record 30 of Set 4 | dourbali
# Processing Record 31 of Set 4 | northam
# Processing Record 32 of Set 4 | danjiangkou
# Processing Record 33 of Set 4 | sao filipe
# Processing Record 34 of Set 4 | mao
# Processing Record 35 of Set 4 | san pedro de macoris
# Processing Record 36 of Set 4 | ilulissat
# Processing Record 37 of Set 4 | atlantic city
# Processing Record 38 of Set 4 | calama
# Processing Record 39 of Set 4 | tasiilaq
# Processing Record 40 of Set 4 | flinders
# Processing Record 41 of Set 4 | nokaneng
# Processing Record 42 of Set 4 | fortuna
# Processing Record 43 of Set 4 | hilo
# Processing Record 44 of Set 4 | talaja
# Processing Record 45 of Set 4 | mizan teferi
# Processing Record 46 of Set 4 | norton
# Processing Record 47 of Set 4 | mutoko
# Processing Record 48 of Set 4 | san cristobal
# Processing Record 49 of Set 4 | torbay
# Processing Record 50 of Set 4 | tunceli
# Processing Record 1 of Set 5 | dingle
# Processing Record 2 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 5 | byron bay
# Processing Record 4 of Set 5 | fort nelson
# Processing Record 5 of Set 5 | burgeo
# Processing Record 6 of Set 5 | walvis bay
# Processing Record 7 of Set 5 | bengkulu
# Processing Record 8 of Set 5 | putnam
# Processing Record 9 of Set 5 | tuatapere
# Processing Record 10 of Set 5 | san andres
# Processing Record 11 of Set 5 | pyaozerskiy
# Processing Record 12 of Set 5 | cayenne
# Processing Record 13 of Set 5 | huarmey
# Processing Record 14 of Set 5 | sheridan
# Processing Record 15 of Set 5 | tambul
# City not found. Skipping...
# Processing Record 16 of Set 5 | mahmudia
# Processing Record 17 of Set 5 | isangel
# Processing Record 18 of Set 5 | san pablo
# Processing Record 19 of Set 5 | caravelas
# Processing Record 20 of Set 5 | weston
# Processing Record 21 of Set 5 | nemuro
# Processing Record 22 of Set 5 | norman wells
# Processing Record 23 of Set 5 | gat
# Processing Record 24 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 5 | cabra
# Processing Record 26 of Set 5 | sibiti
# Processing Record 27 of Set 5 | touros
# Processing Record 28 of Set 5 | dromolaxia
# Processing Record 29 of Set 5 | wajima
# Processing Record 30 of Set 5 | cam pha
# City not found. Skipping...
# Processing Record 31 of Set 5 | teguise
# Processing Record 32 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 33 of Set 5 | eenhana
# Processing Record 34 of Set 5 | dianopolis
# City not found. Skipping...
# Processing Record 35 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 5 | arraial do cabo
# Processing Record 37 of Set 5 | mahebourg
# Processing Record 38 of Set 5 | metu
# Processing Record 39 of Set 5 | codrington
# Processing Record 40 of Set 5 | saint-junien
# Processing Record 41 of Set 5 | dzaoudzi
# Processing Record 42 of Set 5 | tura
# Processing Record 43 of Set 5 | lac du bonnet
# Processing Record 44 of Set 5 | east london
# Processing Record 45 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 46 of Set 5 | cidreira
# Processing Record 47 of Set 5 | vostok
# Processing Record 48 of Set 5 | esperance
# Processing Record 49 of Set 5 | wanning
# Processing Record 50 of Set 5 | tynda
# Processing Record 1 of Set 6 | abha
# Processing Record 2 of Set 6 | muros
# Processing Record 3 of Set 6 | arlit
# Processing Record 4 of Set 6 | cap malheureux
# Processing Record 5 of Set 6 | nanortalik
# Processing Record 6 of Set 6 | tlacotalpan
# Processing Record 7 of Set 6 | villarrica
# Processing Record 8 of Set 6 | labytnangi
# Processing Record 9 of Set 6 | chapais
# Processing Record 10 of Set 6 | sao gabriel da cachoeira
# Processing Record 11 of Set 6 | paka
# Processing Record 12 of Set 6 | klyuchi
# Processing Record 13 of Set 6 | roma
# Processing Record 14 of Set 6 | guerrero negro
# Processing Record 15 of Set 6 | sambava
# Processing Record 16 of Set 6 | rubtsovsk
# Processing Record 17 of Set 6 | ewa beach
# Processing Record 18 of Set 6 | kainantu
# Processing Record 19 of Set 6 | mgandu
# Processing Record 20 of Set 6 | angoche
# Processing Record 21 of Set 6 | puerto palomas
# Processing Record 22 of Set 6 | umm kaddadah
# Processing Record 23 of Set 6 | jacareacanga
# Processing Record 24 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 6 | sinjai
# Processing Record 26 of Set 6 | pevek
# Processing Record 27 of Set 6 | thomasville
# Processing Record 28 of Set 6 | togul
# Processing Record 29 of Set 6 | rundu
# Processing Record 30 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 6 | boende
# Processing Record 32 of Set 6 | tulle
# Processing Record 33 of Set 6 | ahipara
# Processing Record 34 of Set 6 | aripuana
# Processing Record 35 of Set 6 | buchanan
# Processing Record 36 of Set 6 | omboue
# Processing Record 37 of Set 6 | play cu
# City not found. Skipping...
# Processing Record 38 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 6 | faya
# Processing Record 40 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 6 | grand gaube
# Processing Record 42 of Set 6 | paamiut
# Processing Record 43 of Set 6 | vila velha
# Processing Record 44 of Set 6 | kimbe
# Processing Record 45 of Set 6 | srednekolymsk
# Processing Record 46 of Set 6 | rocha
# Processing Record 47 of Set 6 | rio gallegos
# Processing Record 48 of Set 6 | oyo
# Processing Record 49 of Set 6 | palaiokhora
# City not found. Skipping...
# Processing Record 50 of Set 6 | port lavaca
# Processing Record 1 of Set 7 | olafsvik
# Processing Record 2 of Set 7 | padang
# Processing Record 3 of Set 7 | bundaberg
# Processing Record 4 of Set 7 | newport
# Processing Record 5 of Set 7 | bogale
# Processing Record 6 of Set 7 | asau
# Processing Record 7 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 7 | tyrma
# Processing Record 9 of Set 7 | raudeberg
# Processing Record 10 of Set 7 | carballo
# Processing Record 11 of Set 7 | palmer
# Processing Record 12 of Set 7 | kumluca
# Processing Record 13 of Set 7 | margate
# Processing Record 14 of Set 7 | tukrah
# Processing Record 15 of Set 7 | cururupu
# Processing Record 16 of Set 7 | tucdao
# Processing Record 17 of Set 7 | hamilton
# Processing Record 18 of Set 7 | qasigiannguit
# Processing Record 19 of Set 7 | baykit
# Processing Record 20 of Set 7 | chissamba
# Processing Record 21 of Set 7 | geraldton
# Processing Record 22 of Set 7 | tres arroyos
# Processing Record 23 of Set 7 | avera
# Processing Record 24 of Set 7 | carnarvon
# Processing Record 25 of Set 7 | comodoro rivadavia
# Processing Record 26 of Set 7 | yulara
# Processing Record 27 of Set 7 | caborca
# Processing Record 28 of Set 7 | blythe
# Processing Record 29 of Set 7 | alofi
# Processing Record 30 of Set 7 | juneau
# Processing Record 31 of Set 7 | batemans bay
# Processing Record 32 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 7 | sug-aksy
# City not found. Skipping...
# Processing Record 34 of Set 7 | eirunepe
# Processing Record 35 of Set 7 | vallenar
# Processing Record 36 of Set 7 | hamada
# Processing Record 37 of Set 7 | khuzhir
# Processing Record 38 of Set 7 | piro
# Processing Record 39 of Set 7 | ucluelet
# Processing Record 40 of Set 7 | itoman
# Processing Record 41 of Set 7 | birmingham
# Processing Record 42 of Set 7 | truro
# Processing Record 43 of Set 7 | thompson
# Processing Record 44 of Set 7 | vestmannaeyjar
# Processing Record 45 of Set 7 | buenavista
# Processing Record 46 of Set 7 | podporozhye
# Processing Record 47 of Set 7 | cairns
# Processing Record 48 of Set 7 | tazovskiy
# Processing Record 49 of Set 7 | behshahr
# Processing Record 50 of Set 7 | libertador general san martin
# Processing Record 1 of Set 8 | nacala
# Processing Record 2 of Set 8 | okhotsk
# Processing Record 3 of Set 8 | kloulklubed
# Processing Record 4 of Set 8 | lexington
# Processing Record 5 of Set 8 | lithgow
# Processing Record 6 of Set 8 | kerema
# Processing Record 7 of Set 8 | bagdarin
# Processing Record 8 of Set 8 | quesnel
# Processing Record 9 of Set 8 | sierra vista
# Processing Record 10 of Set 8 | murgab
# Processing Record 11 of Set 8 | gladstone
# Processing Record 12 of Set 8 | borogontsy
# Processing Record 13 of Set 8 | grindavik
# Processing Record 14 of Set 8 | nizhniy tsasuchey
# Processing Record 15 of Set 8 | xacmaz
# Processing Record 16 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 17 of Set 8 | jalu
# Processing Record 18 of Set 8 | matay
# Processing Record 19 of Set 8 | agadez
# Processing Record 20 of Set 8 | north bend
# Processing Record 21 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 8 | kulhudhuffushi
# Processing Record 23 of Set 8 | portel
# Processing Record 24 of Set 8 | coihaique
# Processing Record 25 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 8 | ancud
# Processing Record 27 of Set 8 | mosquera
# Processing Record 28 of Set 8 | tilichiki
# Processing Record 29 of Set 8 | bathsheba
# Processing Record 30 of Set 8 | ust-maya
# Processing Record 31 of Set 8 | svetlogorsk
# Processing Record 32 of Set 8 | haines junction
# Processing Record 33 of Set 8 | bandrele
# Processing Record 34 of Set 8 | yarovoye
# Processing Record 35 of Set 8 | olecko
# Processing Record 36 of Set 8 | tual
# Processing Record 37 of Set 8 | sinnamary
# Processing Record 38 of Set 8 | baghdad
# Processing Record 39 of Set 8 | orbetello
# Processing Record 40 of Set 8 | taoudenni
# Processing Record 41 of Set 8 | kashi
# Processing Record 42 of Set 8 | komsomolskiy
# Processing Record 43 of Set 8 | trairi
# Processing Record 44 of Set 8 | belyy yar
# Processing Record 45 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 8 | usak
# Processing Record 47 of Set 8 | homer
# Processing Record 48 of Set 8 | luganville
# Processing Record 49 of Set 8 | gongzhuling
# Processing Record 50 of Set 8 | salta
# Processing Record 1 of Set 9 | inverell
# Processing Record 2 of Set 9 | ola
# Processing Record 3 of Set 9 | inongo
# Processing Record 4 of Set 9 | kukes
# Processing Record 5 of Set 9 | forecariah
# Processing Record 6 of Set 9 | pyapon
# Processing Record 7 of Set 9 | bonavista
# Processing Record 8 of Set 9 | jieshi
# Processing Record 9 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 10 of Set 9 | doka
# Processing Record 11 of Set 9 | hit
# Processing Record 12 of Set 9 | trapani
# Processing Record 13 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 9 | ostrovnoy
# Processing Record 15 of Set 9 | moron
# Processing Record 16 of Set 9 | ahtopol
# Processing Record 17 of Set 9 | san patricio
# Processing Record 18 of Set 9 | burley
# Processing Record 19 of Set 9 | olga
# Processing Record 20 of Set 9 | fare
# Processing Record 21 of Set 9 | pangnirtung
# Processing Record 22 of Set 9 | sao miguel
# Processing Record 23 of Set 9 | kahului
# Processing Record 24 of Set 9 | payo
# Processing Record 25 of Set 9 | pacific grove
# Processing Record 26 of Set 9 | canyon
# Processing Record 27 of Set 9 | sur
# Processing Record 28 of Set 9 | santa cruz del sur
# Processing Record 29 of Set 9 | ta khmau
# Processing Record 30 of Set 9 | sao felix do xingu
# Processing Record 31 of Set 9 | vila franca do campo
# Processing Record 32 of Set 9 | fairbanks
# Processing Record 33 of Set 9 | winnemucca
# Processing Record 34 of Set 9 | idukki
# Processing Record 35 of Set 9 | hofn
# Processing Record 36 of Set 9 | akyab
# Processing Record 37 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 9 | zlutice
# Processing Record 39 of Set 9 | sterling
# Processing Record 40 of Set 9 | tonk
# Processing Record 41 of Set 9 | hirado
# Processing Record 42 of Set 9 | hanchuan
# Processing Record 43 of Set 9 | marinette
# Processing Record 44 of Set 9 | katherine
# Processing Record 45 of Set 9 | coquimbo
# Processing Record 46 of Set 9 | khvastovichi
# Processing Record 47 of Set 9 | treinta y tres
# Processing Record 48 of Set 9 | anadyr
# Processing Record 49 of Set 9 | fayetteville
# Processing Record 50 of Set 9 | alyangula
# Processing Record 1 of Set 10 | berlevag
# Processing Record 2 of Set 10 | itapaci
# Processing Record 3 of Set 10 | husavik
# Processing Record 4 of Set 10 | seoul
# Processing Record 5 of Set 10 | progreso
# Processing Record 6 of Set 10 | ouadda
# Processing Record 7 of Set 10 | sitka
# Processing Record 8 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 9 of Set 10 | nenita
# Processing Record 10 of Set 10 | itarema
# Processing Record 11 of Set 10 | vanimo
# Processing Record 12 of Set 10 | port hardy
# Processing Record 13 of Set 10 | rawson
# Processing Record 14 of Set 10 | niamey
# Processing Record 15 of Set 10 | uvat
# Processing Record 16 of Set 10 | severnyy
# Processing Record 17 of Set 10 | tieling
# Processing Record 18 of Set 10 | aquiraz
# Processing Record 19 of Set 10 | la rioja
# Processing Record 20 of Set 10 | monte cristi
# City not found. Skipping...
# Processing Record 21 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 22 of Set 10 | northport
# Processing Record 23 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 10 | necochea
# Processing Record 25 of Set 10 | tateyama
# Processing Record 26 of Set 10 | hazorasp
# Processing Record 27 of Set 10 | cascais
# Processing Record 28 of Set 10 | port shepstone
# Processing Record 29 of Set 10 | baoqing
# Processing Record 30 of Set 10 | crotone
# Processing Record 31 of Set 10 | kalulushi
# Processing Record 32 of Set 10 | platteville
# Processing Record 33 of Set 10 | koumac
# Processing Record 34 of Set 10 | balikpapan
# Processing Record 35 of Set 10 | casper
# Processing Record 36 of Set 10 | leshukonskoye
# Processing Record 37 of Set 10 | souillac
# Processing Record 38 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 39 of Set 10 | talnakh
# Processing Record 40 of Set 10 | alamosa
# Processing Record 41 of Set 10 | pisco
# Processing Record 42 of Set 10 | adrar
# Processing Record 43 of Set 10 | ternate
# Processing Record 44 of Set 10 | derzhavinsk
# Processing Record 45 of Set 10 | oktyabrskiy
# Processing Record 46 of Set 10 | syracuse
# Processing Record 47 of Set 10 | ngunguru
# Processing Record 48 of Set 10 | hammerfest
# Processing Record 49 of Set 10 | marrakesh
# Processing Record 50 of Set 10 | nicoya
# Processing Record 1 of Set 11 | dawlatabad
# Processing Record 2 of Set 11 | urengoy
# Processing Record 3 of Set 11 | tirano
# Processing Record 4 of Set 11 | bria
# Processing Record 5 of Set 11 | shar
# Processing Record 6 of Set 11 | benxi
# Processing Record 7 of Set 11 | tanete
# Processing Record 8 of Set 11 | sistranda
# Processing Record 9 of Set 11 | rio tercero
# Processing Record 10 of Set 11 | novaya igirma
# Processing Record 11 of Set 11 | tulum
# Processing Record 12 of Set 11 | eureka
# Processing Record 13 of Set 11 | miramar
# Processing Record 14 of Set 11 | namatanai
# Processing Record 15 of Set 11 | yarada
# Processing Record 16 of Set 11 | udachnyy
# Processing Record 17 of Set 11 | villazon
# Processing Record 18 of Set 11 | lalibela
# Processing Record 19 of Set 11 | kluang
# Processing Record 20 of Set 11 | vilcun
# Processing Record 21 of Set 11 | itaperuna
# Processing Record 22 of Set 11 | birao
# Processing Record 23 of Set 11 | mount isa
# Processing Record 24 of Set 11 | dubbo
# Processing Record 25 of Set 11 | evensk
# Processing Record 26 of Set 11 | porbandar
# Processing Record 27 of Set 11 | itaituba
# Processing Record 28 of Set 11 | krasnoarmeysk
# Processing Record 29 of Set 11 | ramhormoz
# Processing Record 30 of Set 11 | veraval
# Processing Record 31 of Set 11 | pahalgam
# Processing Record 32 of Set 11 | shibetsu
# Processing Record 33 of Set 11 | fort-shevchenko
# Processing Record 34 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 35 of Set 11 | boa vista
# Processing Record 36 of Set 11 | pangkalanbuun
# Processing Record 37 of Set 11 | san fernando
# Processing Record 38 of Set 11 | sampit
# Processing Record 39 of Set 11 | omaruru
# Processing Record 40 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 11 | burica
# City not found. Skipping...
# Processing Record 42 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 11 | alexandria
# Processing Record 44 of Set 11 | port lincoln
# Processing Record 45 of Set 11 | atar
# Processing Record 46 of Set 11 | bokony
# Processing Record 47 of Set 11 | kargat
# Processing Record 48 of Set 11 | lima
# Processing Record 49 of Set 11 | barvinkove
# Processing Record 50 of Set 11 | alihe
# Processing Record 1 of Set 12 | kaitangata
# Processing Record 2 of Set 12 | uspenka
# Processing Record 3 of Set 12 | ponor
# Processing Record 4 of Set 12 | matara
# Processing Record 5 of Set 12 | sulangan
# Processing Record 6 of Set 12 | conakry
# Processing Record 7 of Set 12 | carutapera
# Processing Record 8 of Set 12 | takoradi
# Processing Record 9 of Set 12 | kavaratti
# Processing Record 10 of Set 12 | ishinomaki
# Processing Record 11 of Set 12 | galesong
# Processing Record 12 of Set 12 | cuicatlan
# Processing Record 13 of Set 12 | opuwo
# Processing Record 14 of Set 12 | noumea
# Processing Record 15 of Set 12 | neuquen
# Processing Record 16 of Set 12 | orcopampa
# Processing Record 17 of Set 12 | kuytun
# Processing Record 18 of Set 12 | baker city
# Processing Record 19 of Set 12 | yeysk
# Processing Record 20 of Set 12 | kuhdasht
# Processing Record 21 of Set 12 | strezhevoy
# Processing Record 22 of Set 12 | sumkino
# Processing Record 23 of Set 12 | san antonio palopo
# Processing Record 24 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 25 of Set 12 | ye
# City not found. Skipping...
# Processing Record 26 of Set 12 | druzhba
# Processing Record 27 of Set 12 | lavrentiya
# Processing Record 28 of Set 12 | zaqatala
# Processing Record 29 of Set 12 | merauke
# Processing Record 30 of Set 12 | bemidji
# Processing Record 31 of Set 12 | yining
# Processing Record 32 of Set 12 | torres
# Processing Record 33 of Set 12 | savelugu
# Processing Record 34 of Set 12 | mehamn
# Processing Record 35 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 36 of Set 12 | poum
# Processing Record 37 of Set 12 | ghoti
# Processing Record 38 of Set 12 | sisimiut
# Processing Record 39 of Set 12 | temnikov
# Processing Record 40 of Set 12 | ambilobe
# Processing Record 41 of Set 12 | kitimat
# Processing Record 42 of Set 12 | glushkovo
# Processing Record 43 of Set 12 | knysna
# Processing Record 44 of Set 12 | prado
# Processing Record 45 of Set 12 | altar
# Processing Record 46 of Set 12 | maniitsoq
# Processing Record 47 of Set 12 | bay city
# Processing Record 48 of Set 12 | dunedin
# Processing Record 49 of Set 12 | antofagasta
# Processing Record 50 of Set 12 | pucallpa
# Processing Record 1 of Set 13 | westport
# Processing Record 2 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 3 of Set 13 | burnie
# Processing Record 4 of Set 13 | laramie
# Processing Record 5 of Set 13 | guantanamo
# Processing Record 6 of Set 13 | wittmund
# Processing Record 7 of Set 13 | tianpeng
# Processing Record 8 of Set 13 | merrill
# Processing Record 9 of Set 13 | cairo
# Processing Record 10 of Set 13 | areni
# Processing Record 11 of Set 13 | bubaque
# Processing Record 12 of Set 13 | gotsu
# Processing Record 13 of Set 13 | lompoc
# Processing Record 14 of Set 13 | zhongshu
# Processing Record 15 of Set 13 | wonthaggi
# Processing Record 16 of Set 13 | ostrzeszow
# Processing Record 17 of Set 13 | eyrarbakki
# Processing Record 18 of Set 13 | panaba
# Processing Record 19 of Set 13 | saint-pierre
# Processing Record 20 of Set 13 | fonte boa
# Processing Record 21 of Set 13 | marsa matruh
# Processing Record 22 of Set 13 | joacaba
# Processing Record 23 of Set 13 | pozoblanco
# Processing Record 24 of Set 13 | mocuba
# Processing Record 25 of Set 13 | chiredzi
# Processing Record 26 of Set 13 | nishihara
# Processing Record 27 of Set 13 | jhalida
# Processing Record 28 of Set 13 | shimoda
# Processing Record 29 of Set 13 | camacha
# Processing Record 30 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 31 of Set 13 | barranca
# Processing Record 32 of Set 13 | plettenberg bay
# Processing Record 33 of Set 13 | fraserburgh
# Processing Record 34 of Set 13 | wenling
# Processing Record 35 of Set 13 | boguchany
# Processing Record 36 of Set 13 | fayaoue
# Processing Record 37 of Set 13 | whitehorse
# Processing Record 38 of Set 13 | saint-francois
# Processing Record 39 of Set 13 | empalme
# Processing Record 40 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 42 of Set 13 | oistins
# Processing Record 43 of Set 13 | tiznit
# Processing Record 44 of Set 13 | rebrikha
# Processing Record 45 of Set 13 | les escoumins
# Processing Record 46 of Set 13 | adzope
# Processing Record 47 of Set 13 | pangoa
# Processing Record 48 of Set 13 | zerbst
# Processing Record 49 of Set 13 | maltahohe
# Processing Record 50 of Set 13 | ugoofaaru
# Processing Record 1 of Set 14 | mariental
# Processing Record 2 of Set 14 | ust-omchug
# Processing Record 3 of Set 14 | labuhan
# Processing Record 4 of Set 14 | abu dhabi
# Processing Record 5 of Set 14 | kodinsk
# Processing Record 6 of Set 14 | luanda
# Processing Record 7 of Set 14 | kirn
# Processing Record 8 of Set 14 | treuchtlingen
# Processing Record 9 of Set 14 | zhaotong
# Processing Record 10 of Set 14 | ballinasloe
# Processing Record 11 of Set 14 | tiarei
# Processing Record 12 of Set 14 | nuuk
# Processing Record 13 of Set 14 | peniche
# Processing Record 14 of Set 14 | general roca
# Processing Record 15 of Set 14 | kholm
# Processing Record 16 of Set 14 | belen
# Processing Record 17 of Set 14 | hokitika
# Processing Record 18 of Set 14 | estevan
# Processing Record 19 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 14 | princeton
# Processing Record 21 of Set 14 | teknaf
# Processing Record 22 of Set 14 | kingsland
# Processing Record 23 of Set 14 | patrocinio
# Processing Record 24 of Set 14 | taltal
# Processing Record 25 of Set 14 | iquique
# Processing Record 26 of Set 14 | kawalu
# Processing Record 27 of Set 14 | inuvik
# Processing Record 28 of Set 14 | mpika
# Processing Record 29 of Set 14 | havelock
# Processing Record 30 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 31 of Set 14 | arrecife
# Processing Record 32 of Set 14 | le port
# Processing Record 33 of Set 14 | teya
# Processing Record 34 of Set 14 | krasnoselkup
# Processing Record 35 of Set 14 | javanrud
# Processing Record 36 of Set 14 | yataity del norte
# Processing Record 37 of Set 14 | alzamay
# Processing Record 38 of Set 14 | hayden
# Processing Record 39 of Set 14 | kupang
# Processing Record 40 of Set 14 | nelson bay
# Processing Record 41 of Set 14 | college
# Processing Record 42 of Set 14 | sorland
# Processing Record 43 of Set 14 | ciudad bolivar
# Processing Record 44 of Set 14 | belaya gora
# Processing Record 45 of Set 14 | imbituba
# Processing Record 46 of Set 14 | qarqin
# Processing Record 47 of Set 14 | deputatskiy
# Processing Record 48 of Set 14 | karmaskaly
# Processing Record 49 of Set 14 | qitaihe
# Processing Record 50 of Set 14 | kiunga
# Processing Record 1 of Set 15 | beyneu
# Processing Record 2 of Set 15 | tucumcari
# Processing Record 3 of Set 15 | oranjestad
# Processing Record 4 of Set 15 | gambissara
# Processing Record 5 of Set 15 | aden
# Processing Record 6 of Set 15 | ormara
# Processing Record 7 of Set 15 | whitecourt
# Processing Record 8 of Set 15 | soldotna
# Processing Record 9 of Set 15 | palana
# Processing Record 10 of Set 15 | kunashak
# Processing Record 11 of Set 15 | artigas
# Processing Record 12 of Set 15 | salinopolis
# Processing Record 13 of Set 15 | ismailia
# Processing Record 14 of Set 15 | marawi
# Processing Record 15 of Set 15 | bozeman
# Processing Record 16 of Set 15 | grenada
# Processing Record 17 of Set 15 | carlyle
# Processing Record 18 of Set 15 | sao jose da coroa grande
# Processing Record 19 of Set 15 | port hedland
# Processing Record 20 of Set 15 | dallas
# Processing Record 21 of Set 15 | athabasca
# Processing Record 22 of Set 15 | kincardine
# Processing Record 23 of Set 15 | karasjok
# Processing Record 24 of Set 15 | lalsk
# Processing Record 25 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 15 | kourou
# Processing Record 27 of Set 15 | skibbereen
# Processing Record 28 of Set 15 | aksarka
# Processing Record 29 of Set 15 | manta
# Processing Record 30 of Set 15 | usinsk
# Processing Record 31 of Set 15 | bilma
# Processing Record 32 of Set 15 | coihueco
# Processing Record 33 of Set 15 | meybod
# Processing Record 34 of Set 15 | henties bay
# Processing Record 35 of Set 15 | virginia beach
# Processing Record 36 of Set 15 | lethem
# Processing Record 37 of Set 15 | kerman
# Processing Record 38 of Set 15 | rio grande
# Processing Record 39 of Set 15 | yarim
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 677

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Georgetown   5.4112  100.3354     80.53        80          20
# 1         Bereda  43.2686   -7.5406     52.14       100         100
# 2   Punta Arenas -53.1500  -70.9167     55.51        88          75
# 3       Khatanga  71.9667  102.5000    -42.47        96          10
# 4       Belmonte -15.8631  -38.8828     76.78        82          45
# 5           Lata  40.1629   -8.3327     55.08        97         100
# 6    Tuktoyaktuk  69.4541 -133.0374     -2.20        84         100
# 7  Kasongo-Lunda  -6.4667   16.8167     69.66        97          97
# 8        Rikitea -23.1203 -134.9692     77.09        72         100
# 9         Usevya  -7.1000   31.2333     64.96        95         100
#
#    Wind Speed Country Current Description
# 0        2.30      MY          few clouds
# 1        3.80      ES     overcast clouds
# 2        5.75      CL       broken clouds
# 3        4.54      RU           clear sky
# 4        5.97      BR    scattered clouds
# 5       10.71      PT     overcast clouds
# 6       16.11      CA          light snow
# 7        0.76      CD     overcast clouds
# 8        1.92      PF          light rain
# 9        1.34      TZ     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_columns]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Georgetown      MY   5.4112  100.3354     80.53        80          20
# 1         Bereda      ES  43.2686   -7.5406     52.14       100         100
# 2   Punta Arenas      CL -53.1500  -70.9167     55.51        88          75
# 3       Khatanga      RU  71.9667  102.5000    -42.47        96          10
# 4       Belmonte      BR -15.8631  -38.8828     76.78        82          45
# 5           Lata      PT  40.1629   -8.3327     55.08        97         100
# 6    Tuktoyaktuk      CA  69.4541 -133.0374     -2.20        84         100
# 7  Kasongo-Lunda      CD  -6.4667   16.8167     69.66        97          97
# 8        Rikitea      PF -23.1203 -134.9692     77.09        72         100
# 9         Usevya      TZ  -7.1000   31.2333     64.96        95         100
#
#    Wind Speed Current Description
# 0        2.30          few clouds
# 1        3.80     overcast clouds
# 2        5.75       broken clouds
# 3        4.54           clear sky
# 4        5.97    scattered clouds
# 5       10.71     overcast clouds
# 6       16.11          light snow
# 7        0.76     overcast clouds
# 8        1.92          light rain
# 9        1.34     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
